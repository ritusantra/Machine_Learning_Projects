# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler, PowerTransformer, FunctionTransformer

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline

import pickle

# %%
df = pd.read_csv('shipment_price.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8504 entries, 0 to 8503
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Line Item Quantity  8504 non-null   int64
#  1   Line Item Value     8504 non-null   float64
#  2   Pack Price          8504 non-null   float64
#  3   Country             8504 non-null   object
#  4   Vendor              8504 non-null   object
#  5   Product Group       8504 non-null   object
#  6   Weight (Kilograms)  8504 non-null   int64
#  7   Shipment Mode       8504 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 531.6+ KB

# %% [markdown]
# ## Feature Encoding

# %%
encoder_pipeline = Pipeline(steps=[('ohe',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'))])

# %% [markdown]
# ## Scale & Transform Features

# %%
scaling_trf = Pipeline(steps=[
    ('tranform',PowerTransformer(method='yeo-johnson')),
    ('scaling',StandardScaler())
])

# %% [markdown]
# ## Pipeline

# %%
trf = ColumnTransformer([
    ('encoder_pipeline',encoder_pipeline,['Vendor', 'Product Group','Country']),
    ('scaling_trf',scaling_trf,['Line Item Quantity', 'Line Item Value', 'Pack Price','Weight (Kilograms)'])
],remainder='passthrough')

# %%
pipeline = make_pipeline(trf)

# %%
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encoder_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['Vendor', 'Product Group',
#                                                    'Country']),
#                                                  ('scaling_trf',
#                                                   Pipeline(steps=[('tranform',
#                                                                    PowerTransformer()),
# ...

# %% [markdown]
# ## Save Pipeline

# %%
with open('fe_pipeline.pkl','wb') as f:
    pickle.dump(pipeline, f)
