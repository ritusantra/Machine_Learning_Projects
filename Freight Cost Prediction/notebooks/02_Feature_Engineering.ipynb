# %% [markdown]
# # Feature Engineering

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as pyplot

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler, PowerTransformer, FunctionTransformer

from sklearn.pipeline import Pipeline,make_pipeline

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
vendor_invoice = pd.read_csv('vendor_invoice.csv')

# %% [markdown]
# ### Feature Scaling

# %%
num_trf = Pipeline(steps=[('scaling',StandardScaler())])
trf = ColumnTransformer([('num_trf',num_trf,['Quantity', 'Dollars'])],remainder='passthrough')
feature_engineering_pipeline = make_pipeline(trf)

# %%
feature_engineering_pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_trf',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   ['Quantity', 'Dollars'])]))])

# %% [markdown]
# ### Save Pipeline

# %%
with open('feature_engineering_pipeline.pkl','wb') as f:
    pickle.dump(feature_engineering_pipeline, f)
